# %%
import requests
import io
import base64
from PIL import Image

# %%
requests.post("http://127.0.0.1:8000/prompt/", json={"prompt": "Miniature scene of a dog under a christmas tree"}).json()

# %%
response = requests.get("http://127.0.0.1:8000/check/").json()
img = Image.open(io.BytesIO(base64.b64decode(response['image'])))
display(img)
display(response['prompt'])
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512>
# 'Miniature scene of a dog under a christmas tree'

# %%
while True:
    requests.get("http://127.0.0.1:8000/step/", timeout=300)
# Out:
# <Response [200]>
